# %%
# Este es un comentario: ¡Tu primer código en Python!

# 1. Le pedimos datos al usuario
nombre = input("Por favor, escribe tu nombre: ")

# 2. Mostramos un saludo personalizado
print(f"¡Hola, {nombre}! Te damos la bienvenida al mundo de Python. 🐍")

# 3. Hacemos una operación matemática sencilla
numero = 5
resultado = numero * 2
print(f"¿Sabías que el doble de {numero} es {resultado}?")
# Out:
# Por favor, escribe tu nombre:  DAYREN
# ¡Hola, DAYREN! Te damos la bienvenida al mundo de Python. 🐍
# ¿Sabías que el doble de 5 es 10?
